# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl as opxl

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'col', 'compat
# ...

# %%
df1 = pd.read_excel("../data/raw/data_bal - 20000.xlsx", index_col=0)

# %%
df2 = pd.read_excel("../data/raw/data_imbal - 55000.xlsx", index_col=0)

# %%
df3 = pd.read_csv("../data/raw/URL dataset.csv", index_col=0,skiprows = 1)

# %%
df4 = pd.read_csv("../data/raw/Phishing URLs.csv", index_col=0, skiprows = 1)

# %%
df1
# Out:
#                                                      URLs
# Labels
# 1              http://dbs.vote-friend.com/sg?ref=anything
# 0       https://www.reynoldstransfer.com/versa-lift-fo...
# 1            https://www.halisupportservice.com/Login.php
# 0       https://www.signets.com.br/wp-includes/wlwmani...
# 1       https://docs.google.com/document/d/e/2PACX-1vT...
# ...                                                   ...
# 1           https://messagerievocale56.wixsite.com/orange
# 1       https://06e6f4d3bb4140516.temporary.link/pt/DS...
# 1       http://lbcpszonaseguravialbcp.cub-medisc.com/1...
# 0       https://dljproduce.com/produce-commodity-calen...
# 0                  https://www.vineinternational.org/team
#
# [20000 rows x 1 columns]

# %%
df2
# Out:
#                                                      URLs
# Labels
# 1        https://www.ujhyjhujhyjhyuj.ga/CC_POSTALE/f2a83/
# 1       https://stitch-statichosting-prod.s3.amazonaws...
# 0                 https://www.reservoirgroup.com/careers/
# 0       https://www.camosy.com/themes/juicy/images/doo...
# 0                            https://www.liveapps.com.au/
# ...                                                   ...
# 0               https://www.knaack.com/support/literature
# 0           https://plus.google.com/107396682494324876800
# 0                   https://www.jaegers.com/daily-pricing
# 0       https://www.benhet.be/batonrouge/voorwaarden.html
# 0         https://www.teijincarbon.com/service-and-advice
#
# [55000 rows x 1 columns]

# %%
df3
# Out:
#                                                     legitimate
# https://www.google.com
# https://www.youtube.com                             legitimate
# https://www.facebook.com                            legitimate
# https://www.baidu.com                               legitimate
# https://www.wikipedia.org                           legitimate
# https://www.reddit.com                              legitimate
# ...                                                        ...
# http://ecct-it.com/docmmmnn/aptgd/index.php           phishing
# http://faboleena.com/js/infortis/jquery/plugins...    phishing
# http://faboleena.com/js/infortis/jquery/plugins...    phishing
# http://atualizapj.com/                                phishing
# http://writeassociate.com/test/Portal/inicio/IO...    phishing
#
# [450175 rows x 1 columns]

# %%
df4
# Out:
#                                                         type
# url
# https://docs.google.com/presentation/d/e/2PACX-...  Phishing
# https://btttelecommunniccatiion.weeblysite.com/     Phishing
# https://kq0hgp.webwave.dev/                         Phishing
# https://brittishtele1bt-69836.getresponsesite.com/  Phishing
# https://bt-internet-105056.weeblysite.com/          Phishing
# ...                                                      ...
# http://www.ezblox.site/free/jennifer111/helpdesk    Phishing
# http://www.formbuddy.com/cgi-bin/formdisp.pl?u=...  Phishing
# http://www.formbuddy.com/cgi-bin/formdisp.pl?u=...  Phishing
# http://www.habbocreditosparati.blogspot.com/        Phishing
# http://creditiperhabbogratissicuro100.blogspot....  Phishing
#
# [54807 rows x 1 columns]

# %%
df4.to_csv("../data/raw/newdata1.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df5 = df3.concat(df4)
#
# File d:\Project\Phishing Detection System\phish_venv\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
df4.describe()
# Out:
#             type
# count      54807
# unique         1
# top     Phishing
# freq       54807

# %%
dir(df4)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
df4.count()
# Out:
# type    54807
# dtype: int64

# %%
func
