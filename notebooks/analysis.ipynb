# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl as opxl

# %%
df1 = pd.read_excel("../data/raw/data_bal - 20000.xlsx")

# %%
df1
# Out:
#        Labels                                               URLs
# 0           1         http://dbs.vote-friend.com/sg?ref=anything
# 1           0  https://www.reynoldstransfer.com/versa-lift-fo...
# 2           1       https://www.halisupportservice.com/Login.php
# 3           0  https://www.signets.com.br/wp-includes/wlwmani...
# 4           1  https://docs.google.com/document/d/e/2PACX-1vT...
# ...       ...                                                ...
# 19995       1      https://messagerievocale56.wixsite.com/orange
# 19996       1  https://06e6f4d3bb4140516.temporary.link/pt/DS...
# 19997       1  http://lbcpszonaseguravialbcp.cub-medisc.com/1...
# 19998       0  https://dljproduce.com/produce-commodity-calen...
# 19999       0             https://www.vineinternational.org/team
#
# [20000 rows x 2 columns]

# %%
import pandas as pd

df = pd.read_excel("data/raw/data_bal - 20000.xlsx")
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel("data/raw/data_bal - 20000.xlsx")
#       4 print(df.columns)
#
# File d:\Project\Phishing Detection System\phish_venv\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
# ...
